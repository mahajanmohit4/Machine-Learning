# %%
import pandas as pd
dataframe = pd.DataFrame()

# url = "http://tinyurl.com/titanic-csv"
df = pd.read_csv("Automobile_data.csv")
# show first two rows
print(df.head(2)) # also try tail(2) for last two rows

# show dimensions
print("Dimensions: {}".format(df.shape))
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# Dimensions: (61, 10)

# %%
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df.isnull()
# Out:
#     index  company  body-style  wheel-base  length  engine-type  \
# 0   False    False       False       False   False        False
# 1   False    False       False       False   False        False
# 2   False    False       False       False   False        False
# 3   False    False       False       False   False        False
# 4   False    False       False       False   False        False
# ..    ...      ...         ...         ...     ...          ...
# 56  False    False       False       False   False        False
# 57  False    False       False       False   False        False
# 58  False    False       False       False   False        False
# 59  False    False       False       False   False        False
# 60  False    False       False       False   False        False
#
#     num-of-cylinders  horsepower  average-mileage  price
# 0              False       False            False  False
# 1              False       False            False  False
# ...

# %%
df=pd.read_csv("Automobile_data.csv",na_values={'price':[" ","NaN"],
                                               'stroke':["?","NaN"],
                                               'horsepower':[""]})

# %%
df = pd.read_csv("Automobile_data.csv", na_values={'price':["?","NaN"],
'stroke':["?","NaN"],
'horsepower':["?","NaN"],
'peak-rpm':["?","NAN"],
'average-mileage':["?","NaN"]})
df.head(20)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# 5       5         audi        sedan        99.8   177.3         ohc
# 6       6         audi        wagon       105.8   192.7         ohc
# 7       9          bmw        sedan       101.2   176.8         ohc
# 8      10          bmw        sedan       101.2   176.8         ohc
# 9      11          bmw        sedan       101.2   176.8         ohc
# 10     13          bmw        sedan       103.5   189.0         ohc
# 11     14          bmw        sedan       103.5   193.8         ohc
# 12     15          bmw        sedan       110.0   197.0         ohc
# ...

# %%
df = df.replace('?','NaN')
df = df.replace('n.a','NaN')

# %%
df.replace(df.isnull(),'NaN')
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
print("Dimension :{}".format(df.shape))
# Out:
# Dimension :(61, 10)

# %%
df.columns[-1]
# Out:
# 'price'

# %%
print(df.max())
# Out:
# index                  88
# company             volvo
# body-style          wagon
# wheel-base          120.9
# length              208.1
# engine-type         rotor
# num-of-cylinders      two
# horsepower            288
# average-mileage        47
# price               45400
# dtype: object

# %%
print(df["price"].max(),df["company"].max())
print(df["company"].max())
# Out:
# 45400.0 volvo
# volvo

# %%
df = df [['company','price']][df.price==df['price'].max()]
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
print(df["price"]=45400.0)
# Out:
#   File "<ipython-input-18-f5a4dd7e4d16>", line 1
#     print(df["price"]=45400.0)
#          ^
# SyntaxError: keyword can't be an expression

# %%
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-c87d2c53916f> in <module>
#       1 car_Manufacturers = df.groupby('company')
# ----> 2 toyotaDf = car_Manufacturers.get_group('toyota')
#       3 toyotaDf
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     684         inds = self._get_index(name)
#     685         if not len(inds):
# --> 686             raise KeyError(name)
#     687
#     688         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: 'toyota'

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv")
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
df.count()
# Out:
# index               61
# company             61
# body-style          61
# wheel-base          61
# length              61
# engine-type         61
# num-of-cylinders    61
# horsepower          61
# average-mileage     61
# price               58
# dtype: int64

# %%
df = pd.read_csv("Automobile_data.csv")
df = df[df.company=="toyota"]
df.index
print(df['company'],df['price'])
# df.count()
# Out:
# 48    toyota
# 49    toyota
# 50    toyota
# 51    toyota
# 52    toyota
# 53    toyota
# 54    toyota
# Name: company, dtype: object 48     5348.0
# 49     6338.0
# 50     6488.0
# 51     6918.0
# 52     7898.0
# 53     8778.0
# 54    15750.0
# Name: price, dtype: float64

# %%
df = pd.read_csv("Automobile_data.csv")
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mitsubishi       4
# mercedes-benz    4
# volkswagen       4
# jaguar           3
# alfa-romero      3
# honda            3
# chevrolet        3
# isuzu            3
# porsche          3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %%
df['price'].max
# Out:
# <bound method Series.max of 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64>

# %%
import pandas as pd
df = pd.read_csv("D:\\Python\\Articles\\pandas\\automobile-dataset\\Automobile_data.csv")
car_Manufacturers = df.groupby('company')
priceDf = car_Manufacturers['company','price'].max()
priceDf

# %%
df1=df.groupby('company')['average-mileage'].mean()
df1.round()
# Out:
# company
# alfa-romero      20.0
# audi             20.0
# bmw              19.0
# chevrolet        41.0
# dodge            31.0
# honda            26.0
# isuzu            33.0
# jaguar           14.0
# mazda            28.0
# mercedes-benz    18.0
# mitsubishi       30.0
# nissan           31.0
# porsche          17.0
# toyota           29.0
# volkswagen       32.0
# volvo            23.0
# Name: average-mileage, dtype: float64

# %%
df = df.sort_values(by=['price','company'],['index'], ascending=False)
df.head(5)
# Out:
#   File "<ipython-input-59-ec2680db3ba7>", line 1
#     df = df.sort_values(by=['price','company'],['index'], ascending=False)
#                                               ^
# SyntaxError: positional argument follows keyword argument

# %%
a1=GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
a2=japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
# a1
pd.concat({'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]},{'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900}], keys=["Germany", "Japan")
# Out:
#   File "<ipython-input-65-6d7ab927327c>", line 4
#     pd.concat({'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]},{'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900}], keys=["Germany", "Japan")
#                                                                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)

japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
carsDf2 = pd.DataFrame.from_dict(japaneseCars)

carsDf = pd.concat([carsDf1, carsDf2], keys=["Germany", "Japan"])
carsDf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %%
pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-e4540146601a> in <module>
# ----> 1 pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
#
# NameError: name 'carPriceDf' is not defined

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}

car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

a= pd.DataFrame(Car_Price)

b= pd.DataFrame(car_Horsepower)

df=pd.merge(a, b, on="Company")
df
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
