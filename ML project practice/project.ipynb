# %%
import pandas as pd

# %%
data = pd.read_csv("technical1.csv")

# %%
data.head()
# Out:
#                   Name of Student  P1  P2  P3  HK1  MCQ1  MCQ2  MCQ3   P4  \
# 0          Aakash Santosh Jaiswal  30  20  70    0  32.0    38    38  170
# 1            Aarti Vitthal Patil   30  40  50    0  42.0    41    32  160
# 2  Abhishek Sanjay Deshpande (TL)  30  20  40    0  44.0    27    35  100
# 3          Abhishek Shivaji Pawar  30  10   0    0  22.0    35    31  120
# 4                  Abhishek Singh  30  10  40    0  47.0    41    41  190
#
#              HK2  ADS  MCQ4
# 0             10   25    26
# 1             10   39    19
# 2             10   29    19
# 3  Not Attempted   29    27
# 4             15    0    25

# %%
del data['Technical']

# %%
data.head()
# Out:
#                   Name of Student  P1  P2  P3  HK1  MCQ1  MCQ2  MCQ3   P4  \
# 0          Aakash Santosh Jaiswal  30  20  70    0  32.0    38    38  170
# 1            Aarti Vitthal Patil   30  40  50    0  42.0    41    32  160
# 2  Abhishek Sanjay Deshpande (TL)  30  20  40    0  44.0    27    35  100
# 3          Abhishek Shivaji Pawar  30  10   0    0  22.0    35    31  120
# 4                  Abhishek Singh  30  10  40    0  47.0    41    41  190
#
#              HK2  ADS  MCQ4
# 0             10   25    26
# 1             10   39    19
# 2             10   29    19
# 3  Not Attempted   29    27
# 4             15    0    25

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name of Student  116 non-null    object
#  1   P1               116 non-null    int64
#  2   P2               116 non-null    int64
#  3   P3               116 non-null    int64
#  4   HK1              116 non-null    int64
#  5   MCQ1             115 non-null    float64
#  6   MCQ2             116 non-null    int64
#  7   MCQ3             116 non-null    int64
#  8   P4               116 non-null    int64
#  9   HK2              116 non-null    object
#  10  ADS              116 non-null    int64
#  11  MCQ4             116 non-null    int64
# dtypes: float64(1), int64(9), object(2)
# memory usage: 11.0+ KB

# %%
data.describe()
# Out:
#                P1          P2          P3         HK1        MCQ1        MCQ2  \
# count  116.000000  116.000000  116.000000  116.000000  115.000000  116.000000
# mean    23.448276   20.517241   38.793103    2.327586   37.043478   35.741379
# std     10.962660   11.177993   19.522793    8.060398   10.582501    9.496105
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     20.000000   10.000000   30.000000    0.000000   33.500000   33.000000
# 50%     30.000000   20.000000   40.000000    0.000000   39.000000   38.000000
# 75%     30.000000   30.000000   50.000000    0.000000   44.000000   42.000000
# max     30.000000   50.000000   90.000000   30.000000   50.000000   48.000000
#
#              MCQ3          P4         ADS        MCQ4
# count  116.000000  116.000000  116.000000  116.000000
# mean    36.724138  105.172414   25.965517   22.525862
# std      9.559504   55.112261    9.592507    5.677509
# min      0.000000    0.000000    0.000000    0.000000
# 25%     33.000000   60.000000   23.750000   21.000000
# 50%     38.000000  105.000000   28.000000   24.000000
# 75%     43.000000  150.000000   31.000000   26.000000
# max     50.000000  200.000000   40.000000   30.000000

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F53F7D1488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F53FEB0408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F53FEEC388>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F53FF24488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F53FF5B588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F53FF99E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F53FFCD788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F540004888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F540010488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F540047688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5400ACB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5400E3D88>]],
#       dtype=object)

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split
train_set, test_set  = train_test_split(data, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 92
# Rows in test set: 24

# %%
import seaborn as sns
corr_mat = data.corr()
corr_mat
mask = np.array(corr_mat)
mask[np.tril_indices_from(mask)] = False
fig, ax = plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(corr_mat, mask = mask, vmax = 0.8, square = True, annot = True)
# corr_matrix['MEDV'].sort_values(ascending=False)

# %%
data.shape
# Out:
# (116, 12)

# %%
from pandas.plotting import scatter_matrix
attributes = ["P1","P2","P3","HK1","MCQ1","MCQ2"]
scatter_matrix(data[attributes], figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F5434CBE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5432EBE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5437327C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F54376A548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5437A12C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5437D9048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F543805D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F54383FB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543843988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F54387B908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5438E4F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543920048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F54395A088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543993188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5439CB288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543A04388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543A3D4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543A75548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F543AB3E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543AE8788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543B20888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543B58988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543B8B848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543BA2948>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F543BDCA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543C14B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543C4DC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543C85D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543CBDE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543CF6FC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F543D31108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543D6A248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543DA4388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543DDD388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543E17488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F543E515C8>]],
#       dtype=object)

# %%
data["P1_PRST"] = (data["P1"]/30)*100

# %%
data["P1_PRST"]
data.head()
# Out:
#                   Name of Student  P1  P2  P3  HK1  MCQ1  MCQ2  MCQ3   P4  \
# 0          Aakash Santosh Jaiswal  30  20  70    0  32.0    38    38  170
# 1            Aarti Vitthal Patil   30  40  50    0  42.0    41    32  160
# 2  Abhishek Sanjay Deshpande (TL)  30  20  40    0  44.0    27    35  100
# 3          Abhishek Shivaji Pawar  30  10   0    0  22.0    35    31  120
# 4                  Abhishek Singh  30  10  40    0  47.0    41    41  190
#
#              HK2  ADS  MCQ4  P1_PRST
# 0             10   25    26    100.0
# 1             10   39    19    100.0
# 2             10   29    19    100.0
# 3  Not Attempted   29    27    100.0
# 4             15    0    25    100.0
